# %% [markdown]
# <a href="https://colab.research.google.com/github/buttaakhil/Lasso-Ridge/blob/main/Linear_Lasso_Ridge_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("Salary.csv")
print(dataset.head(1))
# Out:
#    Total Experience  Team Lead Experience  Project Manager Experience  Certifications        Salary
# 0                 7                     2                           4               1  77318.070547

# %%
sns.heatmap(dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
print(lr.score(x_test,y_test)*100)
# Out:
# 94.0614842359922

# %%
lr.coef_
# Out:
# array([2988.17486511, 1898.17107701,  974.70334101,  371.32169738])

# %%
lr.intercept_
# Out:
# 50769.345403297055

# %%
la=Lasso(alpha=0.5)
la.fit(x_train,y_train)
print(la.score(x_test,y_test)*100)
# Out:
# 94.06141809391528

# %%
la.coef_
# Out:
# array([2988.36281651, 1897.93321968,  974.38989783,  371.08360895])

# %%
la.intercept_
# Out:
# 50769.6890046899

# %%
ri=Ridge(alpha=0.5)
ri.fit(x_train,y_train)
print(ri.score(x_test,y_test)*100)
# Out:
# 94.06139406489234

# %%
ri.coef_
# Out:
# array([2988.14443372, 1898.06568023,  974.58190893,  371.20634895])

# %%
ri.intercept_
# Out:
# 50770.347416984405
